# %% [markdown]
# # Logging and Monitoring Basics with tf.contrib.learn

# %%
import os

import numpy as np
import tensorflow as tf

# %%
# Download dataset 
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

if not os.path.exists(IRIS_TRAINING):
    raw = urllib.urlopen(IRIS_TRAINING_URL).read()
    with open(IRIS_TRAINING, "w") as f:
        f.write(raw)

if not os.path.exists(IRIS_TEST):
    raw = urllib.urlopen(IRIS_TEST_URL).read()
    with open(IRIS_TEST, "w") as f:
        f.write(raw)

# Data sets
IRIS_TRAINING = os.path.join("./", "iris_training.csv")
IRIS_TEST = os.path.join("./", "iris_test.csv")

# %%
training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TRAINING, target_dtype=np.int, features_dtype=np.float32)
test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TEST, target_dtype=np.int, features_dtype=np.float32)

# %%
feature_columns = [tf.contrib.layers.real_valued_column("")]

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    test_set.data,
    test_set.target,
    every_n_steps=50)
# Out:
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:268: __init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.

# %%
classifier = tf.contrib.learn.DNNClassifier(
    feature_columns=feature_columns,
    hidden_units=[10, 20, 10],
    n_classes=3,
    model_dir="/tmp/iris_model",
    config=tf.contrib.learn.RunConfig(save_checkpoints_secs=1))
# Out:
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 1, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f91345a6090>, '_model_dir': '/tmp/iris_model', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': None, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_evaluation_master': '', '_master': ''}

# %%
classifier.fit(x=training_set.data,
               y=training_set.target,
               steps=2000,
               monitors=[validation_monitor])
# Out:
# WARNING:tensorflow:From <ipython-input-14-38d1dfa69430>:4: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-14-38d1dfa69430>:4: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6000
# INFO:tensorflow:Saving checkpoints for 6001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0295907, step = 6001
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:49
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6001
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:49
# INFO:tensorflow:Saving dict for global step 6001: accuracy = 0.966667, global_step = 6001, loss = 0.136521
# INFO:tensorflow:Validation (step 6001): loss = 0.136521, global_step = 6001, accuracy = 0.966667
# INFO:tensorflow:Saving checkpoints for 6033 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:49
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6033
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:50
# INFO:tensorflow:Saving dict for global step 6033: accuracy = 0.966667, global_step = 6033, loss = 0.13713
# INFO:tensorflow:Validation (step 6051): loss = 0.13713, global_step = 6033, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 60.6922
# INFO:tensorflow:loss = 0.0293553, step = 6101 (1.634 sec)
# INFO:tensorflow:Saving checkpoints for 6181 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 262.691
# INFO:tensorflow:loss = 0.0291169, step = 6201 (0.381 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:50
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6181
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:51
# INFO:tensorflow:Saving dict for global step 6181: accuracy = 0.966667, global_step = 6181, loss = 0.13999
# INFO:tensorflow:Validation (step 6201): loss = 0.13999, global_step = 6181, accuracy = 0.966667
# INFO:tensorflow:Saving checkpoints for 6286 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 102.176
# INFO:tensorflow:loss = 0.0288921, step = 6301 (0.978 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:51
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6286
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:52
# INFO:tensorflow:Saving dict for global step 6286: accuracy = 0.966667, global_step = 6286, loss = 0.110976
# INFO:tensorflow:Validation (step 6301): loss = 0.110976, global_step = 6286, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 119.901
# INFO:tensorflow:loss = 0.0286628, step = 6401 (0.839 sec)
# INFO:tensorflow:Saving checkpoints for 6407 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:53
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6407
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:53
# INFO:tensorflow:Saving dict for global step 6407: accuracy = 0.966667, global_step = 6407, loss = 0.144377
# INFO:tensorflow:Validation (step 6451): loss = 0.144377, global_step = 6407, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 112.262
# INFO:tensorflow:loss = 0.028444, step = 6501 (0.885 sec)
# INFO:tensorflow:Saving checkpoints for 6554 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 204.524
# INFO:tensorflow:loss = 0.0282408, step = 6601 (0.489 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:54
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6554
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:54
# INFO:tensorflow:Saving dict for global step 6554: accuracy = 0.966667, global_step = 6554, loss = 0.115599
# INFO:tensorflow:Validation (step 6601): loss = 0.115599, global_step = 6554, accuracy = 0.966667
# INFO:tensorflow:Saving checkpoints for 6680 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 115.306
# INFO:tensorflow:loss = 0.0280314, step = 6701 (0.868 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:55
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6680
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:55
# INFO:tensorflow:Saving dict for global step 6680: accuracy = 0.966667, global_step = 6680, loss = 0.117775
# INFO:tensorflow:Validation (step 6701): loss = 0.117775, global_step = 6680, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 126.522
# INFO:tensorflow:loss = 0.0278137, step = 6801 (0.789 sec)
# INFO:tensorflow:Saving checkpoints for 6802 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:56
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6802
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:56
# INFO:tensorflow:Saving dict for global step 6802: accuracy = 0.966667, global_step = 6802, loss = 0.119801
# INFO:tensorflow:Validation (step 6851): loss = 0.119801, global_step = 6802, accuracy = 0.966667
# INFO:tensorflow:Saving checkpoints for 6897 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 90.5109
# INFO:tensorflow:loss = 0.027626, step = 6901 (1.106 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:56
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6897
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:57
# INFO:tensorflow:Saving dict for global step 6897: accuracy = 0.966667, global_step = 6897, loss = 0.15367
# INFO:tensorflow:Validation (step 6901): loss = 0.15367, global_step = 6897, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 138.873
# INFO:tensorflow:loss = 0.0274334, step = 7001 (0.719 sec)
# INFO:tensorflow:Saving checkpoints for 7072 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 282.609
# INFO:tensorflow:loss = 0.027232, step = 7101 (0.354 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:58
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7072
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:58
# INFO:tensorflow:Saving dict for global step 7072: accuracy = 0.966667, global_step = 7072, loss = 0.124525
# INFO:tensorflow:Validation (step 7101): loss = 0.124525, global_step = 7072, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 123.417
# INFO:tensorflow:loss = 0.0270584, step = 7201 (0.810 sec)
# INFO:tensorflow:Saving checkpoints for 7210 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:52:59
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7210
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:52:59
# INFO:tensorflow:Saving dict for global step 7210: accuracy = 0.966667, global_step = 7210, loss = 0.12697
# INFO:tensorflow:Validation (step 7251): loss = 0.12697, global_step = 7210, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 112.598
# INFO:tensorflow:loss = 0.0268794, step = 7301 (0.888 sec)
# INFO:tensorflow:Saving checkpoints for 7353 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 291.867
# INFO:tensorflow:loss = 0.0267122, step = 7401 (0.342 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:53:00
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7353
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:53:00
# INFO:tensorflow:Saving dict for global step 7353: accuracy = 0.966667, global_step = 7353, loss = 0.162033
# INFO:tensorflow:Validation (step 7401): loss = 0.162033, global_step = 7353, accuracy = 0.966667
# INFO:tensorflow:Saving checkpoints for 7496 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 111.007
# INFO:tensorflow:loss = 0.0265313, step = 7501 (0.901 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:53:00
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7496
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:53:01
# INFO:tensorflow:Saving dict for global step 7496: accuracy = 0.966667, global_step = 7496, loss = 0.131882
# INFO:tensorflow:Validation (step 7501): loss = 0.131882, global_step = 7496, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 138.162
# INFO:tensorflow:loss = 0.0263632, step = 7601 (0.724 sec)
# INFO:tensorflow:Saving checkpoints for 7664 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 271.725
# INFO:tensorflow:loss = 0.0262057, step = 7701 (0.368 sec)
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:53:02
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7664
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:53:02
# INFO:tensorflow:Saving dict for global step 7664: accuracy = 0.966667, global_step = 7664, loss = 0.134761
# INFO:tensorflow:Validation (step 7701): loss = 0.134761, global_step = 7664, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 138.06
# INFO:tensorflow:loss = 0.0260605, step = 7801 (0.724 sec)
# INFO:tensorflow:Saving checkpoints for 7842 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:653: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/duyetdev/.local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-24-15:53:03
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-7842
# INFO:tensorflow:Finished evaluation at 2017-07-24-15:53:03
# INFO:tensorflow:Saving dict for global step 7842: accuracy = 0.966667, global_step = 7842, loss = 0.137889
# INFO:tensorflow:Validation (step 7851): loss = 0.137889, global_step = 7842, accuracy = 0.966667
# INFO:tensorflow:global_step/sec: 109.592
# INFO:tensorflow:loss = 0.0258977, step = 7901 (0.912 sec)
# INFO:tensorflow:Saving checkpoints for 7970 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 8000 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0254235.
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x7f912418f910>, 'hidden_units': [10, 20, 10], 'feature_columns': (_RealValuedColumn(column_name='', dimension=1, default_value=None, dtype=tf.float32, normalizer=None),), 'embedding_lr_multipliers': None, 'optimizer': None, 'dropout': None, 'gradient_clip_norm': None, 'activation_fn': <function relu at 0x7f910b4d4140>, 'input_layer_min_slice_size': None})
